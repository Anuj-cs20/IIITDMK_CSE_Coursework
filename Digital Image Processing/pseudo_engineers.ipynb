# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression
import pickle
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor

# %%
data_X=np.load("function_training_X.npy")
data_Y=np.load("function_training_Y.npy")
X=pd.DataFrame(data_X)
y=pd.DataFrame(data_Y)
print(data_Y[:5],data_X[:5])
print(X.head(),y.head())
# Out:
# [-63.514896 -63.425323 -63.33558  -63.245663 -63.15558 ] [-500. -499. -498. -497. -496.]
#        0
# 0 -500.0
# 1 -499.0
# 2 -498.0
# 3 -497.0
# 4 -496.0            0
# 0 -63.514896
# 1 -63.425323
# 2 -63.335579
# 3 -63.245663
# 4 -63.155579

# %%
plt.plot(data_X)
plt.show()

# %%
plt.plot(data_Y)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)
print(X_train.shape,X_test.shape)
# Out:
# (784, 1) (196, 1)

# %%
model2=RandomForestRegressor()
model2.fit(X_train,y_train)
model2.score(X_test,y_test)
y_preds2=model2.predict(X_test)
print(mean_squared_error(y_preds2,y_test))
# Out:
# 0.007129247486154355
# /var/folders/h_/7vnpq61x0hbdqn_m7r6hw_nm0000gn/T/ipykernel_9698/3840783712.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model2.fit(X_train,y_train)

# %%
final_model=RandomForestRegressor()
final_model.fit(X_train,y_train)
# Out:
# /var/folders/h_/7vnpq61x0hbdqn_m7r6hw_nm0000gn/T/ipykernel_9698/3799605444.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   final_model.fit(X_train,y_train)
# RandomForestRegressor()

# %%
pickle.dump(final_model,open('model.pkl','wb'))
